# %%
#HW1


import numpy as np
import matplotlib.pyplot as plt
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')

# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()
#平均平方誤差(均方差) - Mean Squared Error (MSE)
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
#平均絕對誤差 - Mean Absolute Error (MAE)
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae    
    
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 259.863
# The Mean absolute error is 12.656

# %%
#HW2
"""
IEEE-CIS Fraud Detection
1. 你選的這組資料為何重要
a 詐騙偵測，減少民眾受騙與增加正確率，減少顧客抱怨

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
a.企業主提供，蒐集客戶歷史交易記錄
3. 蒐集而來的資料型態為何
結構性資料

4. 這組資料想解決的問題如何評估
分類問題，正確率
"""
# Out:
#   File "<ipython-input-7-e464fd99f013>", line 3
#     mae = MAE = sum(abs(y - yp)) / len(y)
#     ^
# IndentationError: unexpected indent

# %%
#HW3

"""
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

將即時的乘車需求建議提供給司機，降低空車繞行的時間，推升計程車產業服務品質和營收。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
車輛實際載客情況分析乘客熱點
從乘客搭車的歷史數據資料中，找出叫車需求量最多區域，並透過分析當天的時空情境（星期、時段和區域等）和外部事件（天氣、節慶、活動等）及計程車當下位置點，推薦司機優先去哪個區域的熱點載客。

3. 蒐集而來的資料型態為何
結構性資料

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
建立需求量預測模型進行預測，讓司機可以即時掌握潛在客流，並確認是否可以提高業績
"""
